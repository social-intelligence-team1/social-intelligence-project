# %% [markdown]
# advanced_analysis.ipynb
#
# 종합순위점수는 단속건수 순위, 면적당 단속건수 순위, 주차구획당 단속건수 순위를 합산하여 산출하였다. 점수가 낮을수록 여러 기준에서 불법주정차 문제가 상대적으로 두드러지는 지역으로 해석할 수 있다.
#
# 분석 결과, 아름동이 종합순위점수 12점으로 가장 높은 우선순위를 보였고, 조치원읍, 도담동, 소담동, 보람동, 나성동, 한솔동 순으로 상위권에 포함되었다. 이들 지역은 단순히 단속건수가 많거나, 면적 대비 단속 밀도가 높거나, 주차구획 대비 단속 부담이 큰 특성이 복합적으로 나타난 지역이다.
#
# 따라서 이후 원인 분석에서는 종합순위점수가 낮은 상위 지역인 아름동부터 한솔동까지를 주요 분석 대상으로 선정하였다. 즉, 아름동, 조치원읍, 도담동, 소담동, 보람동, 나성동, 한솔동을 중심으로 공동주택 현황, 공공기관 수, 음식점 및 상업시설 분포, 교통량 등 추가 데이터를 결합하여 불법주정차 발생 원인을 비교·분석하고자 한다.
#
# 다만 세롬동, 다정동, 어진동, 고운동, 대평동 등 일부 지역은 주차구획 데이터가 존재하지 않아 주차구획당 단속건수 순위와 종합순위점수를 산출할 수 없었다. 따라서 본 분석에서는 세 지표가 모두 산출된 지역 중 종합순위점수가 낮은 지역을 기준으로 분석 대상을 선정하였다.

# %% [markdown]
# illegal.ipynb
#
# 앞서 선정한 주요 분석 대상 지역인 나성동, 도담동, 보람동, 소담동, 아름동, 조치원읍, 한솔동에 대해 실제 단속이 집중된 세부 장소를 확인하였다. 이는 단순히 행정구역 단위의 단속량만 보는 것이 아니라, 각 지역 내부에서 불법주정차가 어느 지점에 몰려 있는지 파악하기 위한 과정이다.
#
#
# 분석 결과, 각 지역별 상위 단속 장소는 다음과 같이 나타났다.
# 나성동은 국민은행 첫마을지점, 현대자동차 인근, 세종행복타워 주변 등 상업시설과 도로변 중심으로 단속이 많이 발생하였다.
# 이는 나성동의 불법주정차가 단순한 주거지역 문제가 아니라, 상권 이용 과정에서 발생하는 단기 주차 수요와 관련이 있을 가능성을 보여준다. 특히 은행, 영화관, 업무·상가 건물 주변은 방문 차량의 회전이 잦고 잠시 정차하려는 수요가 많기 때문에 도로변 불법주정차가 집중되었을 것으로 해석할 수 있다.
#
# ---
#
# 도담동의 주요 단속 장소는 도담동 먹자골목 인근, 도담복컴 주변, 도담서4길, 양지고등학교 삼거리, 양지초등학교 주변으로 나타났다. 특히 가장 높은 단속건수를 보인 도담동 먹자골목 인근은 음식점과 상업시설이 밀집한 지역으로, 식사 시간대나 저녁 시간대에 방문 차량이 증가하면서 단기 주차 수요가 높아졌을 가능성이 있다. 또한 도담복컴 주변과 도담서4길 역시 생활편의시설과 상권 이용 차량이 모이는 지점으로 볼 수 있다.
#
# 따라서 도담동의 불법주정차는 음식점·상업시설 이용에 따른 방문 차량 증가와 관련이 큰 것으로 해석된다. 여기에 양지고등학교 삼거리와 양지초등학교 주변 단속도 확인되어, 학생 등하교 시간대의 승하차 차량이나 학교 주변 생활도로의 일시 정차 수요도 일부 영향을 주었을 가능성이 있다.
#
# ---
#
# 소담동의 주요 단속 장소는 새샘마을 3단지 정문 앞, 새샘마을 5단지 501동 앞, 새샘마을 2단지 218동 주변 등 공동주택 단지 인근에 집중되어 나타났다. 이는 소담동의 불법주정차가 아파트 단지 주변의 주거지 주차 수요와 관련이 클 가능성을 보여준다. 특히 공동주택 분석에서도 소담동의 주거 관련 지표가 높게 나타났기 때문에, 거주민 차량이나 방문 차량, 등하교·등원 차량 등이 단지 주변 도로에 일시적으로 정차하면서 단속이 발생했을 것으로 해석할 수 있다.
#
# 또한 소담동 법원4로와 아이콤타워 삼거리에서도 단속이 확인되었지만, 상위 단속 장소 대부분이 새샘마을 단지 주변이라는 점에서 소담동의 주요 원인은 공동주택 밀집에 따른 생활권 내 주차 수요로 볼 수 있다. 따라서 소담동은 주거지역 특성이 불법주정차 발생에 큰 영향을 준 지역으로 판단된다.
#
# ---
#
# 보람동의 주요 단속 장소는 호려울마을4단지 앞 사거리, 세종교육청 앞 삼거리, 호려울마을8·9단지 사거리, 금강시티타워 주변, 보람지구대 사거리 등으로 나타났다. 이 중 세종교육청 앞 삼거리 주변에는 교육청, 건설교통국, 시청, 복합커뮤니티센터 등 주요 공공기관과 행정시설이 모여 있어, 민원 처리나 업무 방문을 위한 차량 이동이 집중될 가능성이 크다. 공공기관 주변은 출퇴근 차량, 민원 방문 차량, 업무 차량 등이 함께 몰리기 때문에 단기 주차 및 정차 수요가 높아질 수 있으며, 이로 인해 도로변 불법주정차 단속이 많이 발생한 것으로 해석된다.
#
# 또한 보람동은 호려울마을4단지 앞 사거리와 호려울마을8·9단지 사거리처럼 공동주택 단지 주변에서도 단속이 많이 발생하였다. 공동주택 데이터에서도 보람동의 주거 관련 지표가 비교적 높게 나타난 편이므로, 거주민 차량뿐만 아니라 방문 차량, 등하교·등원 차량, 생활권 이동 차량에 따른 주차 수요도 영향을 주었을 가능성이 있다.
#
# 따라서 보람동의 불법주정차는 공공기관 밀집에 따른 행정업무 방문 차량 증가가 주요 원인으로 보이며, 여기에 공동주택 단지 주변의 생활권 주차 수요가 함께 작용한 결과로 해석할 수 있다.
#
# ---
#
# 한솔동의 주요 단속 장소는 한솔파출소, 한솔동 940 횡단보도, 첫마을4단지 주변, 첫마을301동-308동 사이, 한솔동 1230 인도 등으로 나타났다. 특히 단속건수가 가장 높게 나타난 한솔파출소 주변에는 근린공원과 어린이공원 등 주민들이 이용하는 생활편의 공간이 위치해 있어, 공원 이용 차량이나 보호자 차량의 일시 정차 수요가 발생했을 가능성이 있다. 공원 주변은 짧은 시간 머무르는 차량, 어린이 동반 방문 차량, 산책·운동 목적의 방문 차량 등이 몰릴 수 있어 도로변 주정차가 쉽게 발생하는 공간이다.
#
# 또한 한솔동은 첫마을4단지 주변과 첫마을301동-308동 사이 등 공동주택 단지 인근에서도 단속이 확인되었다. 공동주택 데이터에서도 한솔동의 주거 관련 지표가 비교적 높게 나타난 만큼, 거주민 차량, 방문 차량, 등하교·등원 차량 등 주거지 생활권에서 발생하는 주차 수요도 불법주정차에 영향을 준 것으로 해석된다.
#
# 따라서 한솔동의 불법주정차는 파출소 주변의 생활도로와 공원 이용 수요, 그리고 공동주택 단지 주변의 주거지 주차 수요가 함께 작용한 결과로 볼 수 있다. 특히 횡단보도와 인도 주변 단속이 포함되어 있다는 점에서, 보행공간과 생활권 도로 주변의 일시 정차 문제가 두드러진 지역으로 판단된다.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 공동주택.ipynb
#
# 지역별 공동주택 총세대수를 확인한 결과, 조치원읍, 고운동, 종촌동, 다정동, 도담동, 새롬동, 소담동, 아름동, 보람동 등이 비교적 높은 세대수를 보였다. 이는 해당 지역들이 대규모 주거지역의 성격을 가지고 있으며, 거주민 차량과 방문 차량, 등하교·등원 차량 등 생활권 내 주차 수요가 높게 발생할 가능성이 있음을 의미한다.
#
# 특히 앞서 주요 분석 대상으로 선정한 지역 중 도담동, 소담동, 아름동, 보람동, 한솔동은 공동주택 총세대수가 일정 수준 이상으로 나타났다. 이 중 소담동은 실제 상위 단속 장소가 새샘마을 3단지, 5단지, 2단지 등 아파트 단지 주변에 집중되어 있어 공동주택 밀집에 따른 주거지 주차 수요와의 연관성이 뚜렷하게 확인된다. 보람동 역시 호려울마을 단지 주변 사거리에서 단속이 많이 발생했으며, 공동주택 세대수도 비교적 높은 편이기 때문에 공공기관 방문 차량뿐만 아니라 주거지 생활권 주차 수요도 함께 작용한 것으로 볼 수 있다.
#
# 한솔동의 경우 공동주택 총세대수가 최상위권은 아니지만, 분석 대상 지역 내에서는 주거 관련 지표가 일정 수준 이상으로 나타났고, 실제 단속 장소도 첫마을 단지 주변, 인도, 횡단보도 등 생활도로와 연결되어 있다. 따라서 한솔동의 불법주정차 역시 공동주택 주변의 생활권 주차 수요와 관련이 있는 것으로 해석할 수 있다.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# advanced_analysis.ipynb
#
#
# 나성동은 15시 이후부터 단속건수가 크게 증가하고, 17시~20시 사이에도 높은 수준을 보인다. 앞서 주요 단속 장소로 국민은행 첫마을지점, 현대자동차 인근, 세종행복타워 주변, 메가박스 등이 확인되었는데, 이 장소들은 업무·상업시설과 문화시설이 밀집한 지역이다. 따라서 나성동의 불법주정차는 상업시설을 이용하는 방문 차량이 오후와 저녁 시간대에 집중되면서 발생했을 가능성이 크다. 특히 영화관, 상가, 업무시설 주변에서는 짧은 시간 머무르기 위한 단기 주차 수요가 많아 도로변 정차로 이어질 수 있다.
#
# 도담동도 15시 이후부터 단속건수가 증가하고, 19시~20시 시간대에 비교적 높은 단속건수를 보인다. 도담동의 주요 단속 장소는 도담동 먹자골목 인근, 도담복컴 주변, 도담서4길 등으로 나타났기 때문에, 음식점과 생활편의시설 이용 차량의 영향이 큰 것으로 해석할 수 있다. 특히 먹자골목은 식사 시간대와 저녁 시간대에 방문 차량이 몰리기 쉬운 공간이므로, 저녁 시간대 단속 증가와 상권·음식점 밀집 특성이 연결된다고 볼 수 있다.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 공공기관.ipynb
#
# 공공기관 수 분석 결과, 세종동이 가장 높은 값을 보였고 그다음으로 보람동의 공공기관 수가 높게 나타났다. 이는 보람동이 다른 행정구역에 비해 행정·공공 기능이 비교적 집중된 지역임을 보여준다.
#
# 특히 보람동에는 교육청, 건설교통국, 시청, 복합커뮤니티센터 등 주요 공공기관과 행정시설이 위치해 있어 민원 방문 차량, 업무 차량, 출퇴근 차량 등이 많이 발생할 가능성이 있다. 따라서 보람동의 불법주정차는 공공기관 밀집에 따른 방문 차량 증가의 영향을 받은 것으로 해석할 수 있다.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 음식점.ipynb
#
# 음식점 수 분석 결과, 조치원읍 다음으로 나성동과 보람동의 음식점 수가 높게 나타났다. 이는 두 지역이 음식점과 상업시설이 비교적 밀집한 지역임을 의미한다. 나성동은 실제 단속 장소도 세종행복타워, 메가박스 등 상업시설 주변에 집중되어 있어 상권 이용 차량의 영향이 큰 것으로 볼 수 있다. 보람동 역시 공공기관 밀집 지역인 동시에 음식점 수가 많은 지역이므로, 행정업무 방문 차량과 식사·상권 이용 차량이 함께 불법주정차 발생에 영향을 준 것으로 해석된다.
