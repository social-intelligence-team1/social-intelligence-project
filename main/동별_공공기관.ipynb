# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'AppleGothic'
matplotlib.rcParams['axes.unicode_minus'] = False

url = "http://apis.data.go.kr/5690000/sjPublicIns/sj_00000110"

params = {
    "serviceKey": "73e6daec9a5083347313b30d8b9d78f83ff022356cffe4f6710361a8d4e7f5ea",
    "pageIndex": 1,
    "pageUnit": 100,
    "dataTy": "json"
}

response = requests.get(url, params=params)

print(response.status_code)
print(response.text[:1000])
# Out:
# 200
# {"header":{"resultCode":"00","resultMsg":"NORMAL SERVICE","totalCount":41,"pageIndex":1,"pageUnit":100,"searchCondition":"","searchKeyword":""},"body":{"items":[{"publicInstNm":"세종특별자치시청","roadNmAddr":"세종특별자치시 한누리대로 2130","addr":"세종특별자치시 보람동 663","la":36.4800579900,"lo":127.2890394000,"telno":"044-300-3114","hmpg":"https://www.sejong.go.kr/index.jsp"},{"publicInstNm":"세종특별자치시의회","roadNmAddr":"세종특별자치시 한누리대로 2120","addr":"세종특별자치시 보람동 625-6","la":36.4800210400,"lo":127.2904510000,"telno":"044-300-7000","hmpg":"https://council.sejong.go.kr/"},{"publicInstNm":"보건소","roadNmAddr":"세종특별자치시 조치원읍 대첩로 32","addr":"세종특별자치시 조치원읍 신흥리 53-1","la":36.5959704000,"lo":127.2926766000,"telno":"044-301-2000","hmpg":"https://www.sejong.go.kr/health.do"},{"publicInstNm":"농업기술센터","roadNmAddr":"세종특별자치시 연서면 월하천로 289","addr":"세종특별자치시 연서면 쌍전리 16","la":36.5729994300,"lo":127.2831882000,"telno":"044-301-2500","hmpg":"https://www.sejong.go.kr/adtc.do"},{"publicInstNm":"시설관리사업소","roadNmAddr":"세종특별자치시 전동면 심동로 354","addr

# %%
data = response.json()

items = data["body"]["items"]

df = pd.DataFrame(items)

df
# Out:
#          publicInstNm             roadNmAddr                    addr  \
# 0            세종특별자치시청     세종특별자치시 한누리대로 2130         세종특별자치시 보람동 663
# 1           세종특별자치시의회     세종특별자치시 한누리대로 2120       세종특별자치시 보람동 625-6
# 2                 보건소    세종특별자치시 조치원읍 대첩로 32   세종특별자치시 조치원읍 신흥리 53-1
# 3              농업기술센터   세종특별자치시 연서면 월하천로 289      세종특별자치시 연서면 쌍전리 16
# 4             시설관리사업소    세종특별자치시 전동면 심동로 354      세종특별자치시 전동면 심중리 82
# 5          조치원읍행정복지센터  세종특별자치시 조치원읍 새내16길 17     세종특별자치시 조치원읍 교리 9-1
# 6              연기면사무소     세종특별자치시 연기면 당산로 81  세종특별자치시 연기면 한별리 317-34
# 7              연동면사무소     세종특별자치시 연동면 장욱진로 7    세종특별자치시 연동면 내판리 33-1
# 8           부강면행정복지센터    세종특별자치시 부강면 부강5길 38     세종특별자치시 부강면 부강리 138
# 9           금남면행정복지센터     세종특별자치시 금남면 용포로 57   세종특별자치시 금남면 용포리 122-1
# 10             장군면사무소  세종특별자치시 장군면 장척로 400-1     세종특별자치시 장군면 도계리 167
# 11          연서면행정복지센터    세종특별자치시 연서면 대첩로 238     세종특별자치시 연서면 성제리 293
# 12          전의면행정복지센터  세종특별자치시 전의면 운주산로 1270      세종특별자치시 전의면 읍내리 99
# 13             전동면사무소   세종특별자치시 전동면 운주산로 386     세종특별자치시 전동면 노장리 583
# 14             소정면사무소   세종특별자치시 소정면 소정구길 204      세종특별자치시 소정면 소정리 48
# 15          한솔동행정복지센터        세종특별자치시 노을3로 85         세종특별자치시 한솔동 964
# 16          도담동행정복지센터         세종특별자치시 보람로 77         세종특별자치시 도담동 645
# 17          아름동행정복지센터       세종특별자치시 보듬3로 114        세종특별자치시 아름동 1286
# 31  36.480917  127.292674  044-320-8324
# 32  36.478089  127.286369  044-320-1000
# 33  36.480549  127.291856  044-410-1004
# 34  36.478334  127.292354  044-864-1390
# 35  36.604511  127.299183  044-867-4500
# 36  36.604511  127.299183  044-867-0999
# 37  36.601500  127.303056  044-865-3219
# 38  36.478849  127.285972  044-850-8200
# 39  36.605897  127.293870  044-850-8226
# 40  36.603506  127.296334     1588-7788
#
#                                                  hmpg
# 0                  https://www.sejong.go.kr/index.jsp
# 1                       https://council.sejong.go.kr/
# 2                  https://www.sejong.go.kr/health.do
# 3                    https://www.sejong.go.kr/adtc.do
# 4                https://www.sejong.go.kr/facility.do
# 5          https://www.sejong.go.kr/jochiwon/index.do
# 6            https://www.sejong.go.kr/yeongi/index.do
# 7          https://www.sejong.go.kr/yeondong/index.do
# 8            https://www.sejong.go.kr/bukang/index.do
# 9            https://www.sejong.go.kr/gumnam/index.do
# 10          https://www.sejong.go.kr/janggun/index.do
# 11          https://www.sejong.go.kr/yeonseo/index.do
# 12           https://www.sejong.go.kr/jeonui/index.do
# 13         https://www.sejong.go.kr/jeondong/index.do
# 14           https://www.sejong.go.kr/sojung/index.do
# 15           https://www.sejong.go.kr/hansol/index.do
# 16            https://www.sejong.go.kr/dodam/index.do
# 17            https://www.sejong.go.kr/areum/index.do
# 18         https://www.sejong.go.kr/jongchon/index.do
# 19             https://www.sejong.go.kr/goun/index.do
# 20            https://www.sejong.go.kr/boram/index.do
# 21           https://www.sejong.go.kr/saerom/index.do
# 22          https://www.sejong.go.kr/dajeong/index.do
# 23         https://www.sejong.go.kr/daepyung/index.do
# 24            https://www.sejong.go.kr/sodam/index.do
# 25           https://www.sejong.go.kr/haemil/index.do
# 26           https://www.sejong.go.kr/bangok/index.do
# 27          https://www.sejong.go.kr/naseong/index.do
# 28            https://www.sejong.go.kr/eojin/index.do
# 29                        https://www.sjpolice.go.kr/
# 30        https://www.sjpolice.go.kr/SEO/SJ/index.php
# 31        https://www.sjpolice.go.kr/SEO/NB/index.php
# 32                         https://www.sje.go.kr/sje/
# 33           https://www.koreapost.go.kr/339/index.do
# 34               https://sj.nec.go.kr/sj/main/main.do
# 35  https://daejeon.scourt.go.kr/info/location/new...
# 36  https://daejeon.scourt.go.kr/jibubmgr/regoffic...
# 37              https://www.work.go.kr/sejong/main.do
# 38                 https://d.nts.go.kr/sejong/main.do
# 39                 https://d.nts.go.kr/sejong/main.do
# 40                        https://www.letskorail.com/

# %%
region_map = {
    '한솔': '한솔동',
    '새롬': '새롬동',
    '나성': '나성동',
    '다정': '다정동',
    '도담': '도담동',
    '어진': '어진동',
    '해밀': '해밀동',
    '아름': '아름동',
    '종촌': '종촌동',
    '고운': '고운동',
    '보람': '보람동',
    '대평': '대평동',
    '소담': '소담동',
    '반곡': '반곡동',
    '가람': '가람동',
    
    
    '산울': '산울동',
    '집현': '집현동',
    '세종': '세종동',
    '한별': '한별동',

    '조치원': '조치원읍',

    '연기': '연기면',
    '연동': '연동면',
    '부강': '부강면',
    '금남': '금남면',
    '장군': '장군면',
    '연서': '연서면',
    '전의': '전의면',
    '전동': '전동면',
    '소정': '소정면'
}

# %%
def classify_region(place):
    place = str(place)

    for keyword, region in region_map.items():
        if keyword in place:
            return region

    return '미분류'

# %%
df['행정구역'] = df['addr'].apply(classify_region)

# %%
count_df = df['행정구역'].value_counts()

plt.figure(figsize=(12, 6))
count_df.plot(kind='bar')

plt.title('행정구역별 공공기관 수')
plt.xlabel('행정구역')
plt.ylabel('개수')
plt.xticks(rotation=45)
plt.show()
